# %% [markdown]
# # Análise do COVID no ES - Otimizado e Formatado
# Maiky Barreto da Silva

# %%
# Importando os módulos e o arquivo

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
seaborn.set()

df = pd.read_csv('https://bi.static.es.gov.br/covid19/MICRODADOS.csv', sep = ';', encoding = 'iso8859_15')

# %%
df.DataNotificacao = df.DataNotificacao.astype(np.datetime64)
df.DataObito = df.DataObito.astype(np.datetime64)

# %%
df_confirmados = df.query("Classificacao == 'Confirmados'")
df_confirmados
# Out:
#        DataNotificacao DataCadastro DataDiagnostico DataColeta_RT_PCR  \
# 7           2020-08-19   2020-08-19      2020-08-11               NaN
# 13          2020-08-19   2020-08-19      2020-08-14               NaN
# 20          2020-08-19   2020-08-19      2020-07-29        2020-07-10
# 25          2020-08-19   2020-08-19      2020-08-04               NaN
# 29          2020-08-19   2020-08-19      2020-06-20        2020-06-25
# ...                ...          ...             ...               ...
# 305384      2020-03-13   2020-04-14      2020-03-12        2020-03-13
# 305392      2020-03-13   2020-04-14      2020-03-13        2020-03-15
# 305393      2020-03-13   2020-04-14      2020-03-10        2020-03-12
# 305452      2020-03-06   2020-04-14      2020-03-04        2020-03-06
# 305459      2020-02-29   2020-04-14      2020-02-22        2020-02-29
#
#        DataColetaTesteRapido DataEncerramento DataObito Classificacao  \
# 7                        NaN              NaN       NaT   Confirmados
# 13                2020-08-19              NaN       NaT   Confirmados
# 20                       NaN              NaN       NaT   Confirmados
# 25                       NaN              NaN       NaT   Confirmados
# 29                       NaN       2020-07-03       NaT   Confirmados
# ...                      ...              ...       ...           ...
# 305384                   NaN       2020-04-15       NaT   Confirmados
# 305392                   NaN       2020-05-08       NaT   Confirmados
# 305393                   NaN       2020-05-07       NaT   Confirmados
# 305452                   NaN       2020-05-08       NaT   Confirmados
# 305459                   NaN       2020-04-18       NaT   Confirmados
#
#        Evolucao CriterioConfirmacao  ... ComorbidadeRenal ComorbidadeDiabetes  \
# 7             -        Laboratorial  ...              Não                 Não
# 13            -                   -  ...              Não                 Não
# 20         Cura        Laboratorial  ...              Não                 Não
# 25            -        Laboratorial  ...              Não                 Não
# 29         Cura        Laboratorial  ...              Não                 Sim
# ...         ...                 ...  ...              ...                 ...
# 305384     Cura        Laboratorial  ...              Não                 Sim
# 305392     Cura        Laboratorial  ...              Não                 Não
# 305393     Cura        Laboratorial  ...              Não                 Não
# 305452     Cura        Laboratorial  ...              Não                 Não
# 305459     Cura        Laboratorial  ...              Não                 Não
#
#        ComorbidadeTabagismo ComorbidadeObesidade FicouInternado  \
# 7                       Não                  Não            Não
# 13                      Não                  Não  Não Informado
# 20                      Não                  Não            Não
# 25                      Não                  Não  Não Informado
# 29                      Não                  Não            Não
# ...                     ...                  ...            ...
# 305384                  Não                  Não            Não
# 305392                  Não                  Não  Não Informado
# 305393                  Não                  Não  Não Informado
# 305452                  Não                  Não  Não Informado
# 305459                  Não                  Não  Não Informado
#
#          ViagemBrasil ViagemInternacional ProfissionalSaude PossuiDeficiencia  \
# 7                 Não                 Não               Sim               Não
# 13                Não       Não Informado               Não               Não
# 20                Não                 Não               Sim               Não
# 25      Não Informado       Não Informado               Não               Não
# 29                Não                 Não               Não               Não
# ...               ...                 ...               ...               ...
# 305384            Não                 Não          Ignorado     Não Informado
# 305392  Não Informado                 Sim               Sim     Não Informado
# 305393  Não Informado                 Sim               Não     Não Informado
# 305452  Não Informado                 Sim               Não     Não Informado
# 305459  Não Informado                 Sim     Não Informado     Não Informado
#
#          MoradorDeRua
# 7                 Não
# 13                Não
# 20                Não
# 25                Não
# 29                Não
# ...               ...
# 305384  Não Informado
# 305392  Não Informado
# 305393  Não Informado
# 305452  Não Informado
# 305459  Não Informado
#
# [103090 rows x 37 columns]

# %%
dist_confirmados = df_confirmados.groupby('DataNotificacao').count().DataCadastro

# %%
rm_confirmados = df_confirmados.groupby('DataNotificacao').count().DataCadastro.rolling(14).mean()

# %%
fig1 = plt.figure(figsize = (12,6))
ax1 = plt.axes()
ax1.bar(dist_confirmados[-90:-1].index, dist_confirmados[-90:-1], label = 'Mortos no dia')
ax1.plot(rm_confirmados[-90:-1], color = 'r', label = 'Média móvel de mortos nos últimos 7 dias')
ax1.legend()
ax1.set(title = 'Casos confirmados de COVID-19 nos últimos 90 dias no ES', ylabel = 'Quantidade de Casos confirmados',
        xlabel = 'Data da Notificação')
# Out:
# [Text(0, 0.5, 'Quantidade de Casos confirmados'),
#  Text(0.5, 0, 'Data da Notificação'),
#  Text(0.5, 1.0, 'Casos confirmados de COVID-19 nos últimos 90 dias no ES')]

# %%
df_obitos = df.query("DataObito > '2020'")
df_obitos
# Out:
#        DataNotificacao DataCadastro DataDiagnostico DataColeta_RT_PCR  \
# 408         2020-08-19   2020-08-19      2020-07-29        2020-07-29
# 452         2020-08-19   2020-08-19      2020-08-14        2020-08-17
# 735         2020-08-19   2020-08-19      2020-08-17        2020-08-18
# 1118        2020-08-19   2020-08-19      2020-08-18        2020-08-18
# 1131        2020-08-19   2020-08-19      2020-08-10        2020-08-17
# ...                ...          ...             ...               ...
# 304498      2020-03-26   2020-04-14      2020-03-21        2020-03-26
# 304530      2020-03-26   2020-03-26      2020-03-26        2020-03-26
# 304545      2020-03-25   2020-04-13      2020-03-18        2020-03-25
# 304575      2020-03-25   2020-05-12      2020-03-23        2020-03-26
# 304875      2020-03-20   2020-04-15      2020-03-13        2020-03-20
#
#        DataColetaTesteRapido DataEncerramento  DataObito Classificacao  \
# 408                      NaN              NaN 2020-08-17   Confirmados
# 452                      NaN              NaN 2020-08-17      Suspeito
# 735               2020-08-17              NaN 2020-08-18      Suspeito
# 1118                     NaN              NaN 2020-08-18      Suspeito
# 1131                     NaN       2020-08-19 2020-08-17   Confirmados
# ...                      ...              ...        ...           ...
# 304498                   NaN       2020-04-04 2020-04-04   Confirmados
# 304530            2020-05-27       2020-05-28 2020-05-28   Confirmados
# 304545                   NaN       2020-04-01 2020-04-01   Confirmados
# 304575                   NaN       2020-05-12 2020-03-26   Descartados
# 304875                   NaN       2020-04-29 2020-04-29   Confirmados
#
#                        Evolucao CriterioConfirmacao  ... ComorbidadeRenal  \
# 408         Óbito pelo COVID-19        Laboratorial  ...              Não
# 452                           -        Laboratorial  ...              Não
# 735                           -                   -  ...              Não
# 1118                          -                   -  ...              Não
# 1131        Óbito pelo COVID-19        Laboratorial  ...              Não
# ...                         ...                 ...  ...              ...
# 304498      Óbito pelo COVID-19        Laboratorial  ...                -
# 304530      Óbito pelo COVID-19        Laboratorial  ...              Sim
# 304545      Óbito pelo COVID-19        Laboratorial  ...                -
# 304575  Óbito por outras causas        Laboratorial  ...              Não
# 304875      Óbito pelo COVID-19        Laboratorial  ...              Não
#
#        ComorbidadeDiabetes ComorbidadeTabagismo ComorbidadeObesidade  \
# 408                    Não                  Não                  Não
# 452                    Não                  Não                  Não
# 735                    Sim                  Não                  Não
# 1118                   Não                  Não                  Não
# 1131                   Não                  Não                  Não
# ...                    ...                  ...                  ...
# 304498                   -                    -                  Sim
# 304530                 Sim                  Não                  Não
# 304545                   -                    -                    -
# 304575                 Não                  Não                  Não
# 304875                 Não                  Não                  Não
#
#        FicouInternado   ViagemBrasil ViagemInternacional ProfissionalSaude  \
# 408               Sim       Ignorado            Ignorado               Não
# 452          Ignorado       Ignorado            Ignorado               Não
# 735               Não            Não                 Não               Não
# 1118              Não            Não                 Não               Não
# 1131         Ignorado            Não                 Não               Não
# ...               ...            ...                 ...               ...
# 304498       Ignorado            Não                 Não               Não
# 304530            Sim            Sim       Não Informado               Não
# 304545       Ignorado            Não                 Não          Ignorado
# 304575            Não            Não                 Não               Não
# 304875            Sim  Não Informado       Não Informado               Não
#
#        PossuiDeficiencia MoradorDeRua
# 408                  Não          Não
# 452                  Não          Não
# 735                  Não          Não
# 1118                 Não          Não
# 1131                 Não          Não
# ...                  ...          ...
# 304498               Não          Não
# 304530               Não          Não
# 304545               Não          Não
# 304575               Não          Não
# 304875               Não          Não
#
# [3679 rows x 37 columns]

# %%
total_obitos = df.pivot_table('DataNotificacao', 'DataObito', 'Classificacao', aggfunc='count')
total_obitos
# Out:
# Classificacao  Confirmados  Descartados  Suspeito
# DataObito
# 2020-03-26             NaN          1.0       NaN
# 2020-04-01             4.0          NaN       NaN
# 2020-04-02             3.0          NaN       NaN
# 2020-04-03             NaN          2.0       NaN
# 2020-04-04             1.0          NaN       NaN
# ...                    ...          ...       ...
# 2020-08-15            21.0          4.0       2.0
# 2020-08-16            16.0          1.0       1.0
# 2020-08-17            24.0          4.0       4.0
# 2020-08-18            20.0          5.0       4.0
# 2020-08-19             8.0          1.0       NaN
#
# [139 rows x 3 columns]

# %%
# Restringindo a data para os últimos 90d

obitos_conf = total_obitos.Confirmados[-90:-1]
obitos_susp = total_obitos.Suspeito[-90:-1]
obitos_desc = total_obitos.Descartados[-90:-1]
rm_obitos = obitos_conf.add(obitos_desc.add(obitos_susp, fill_value=0), fill_value=0).rolling(14).mean()

# %%
fig2 = plt.figure(figsize=(12,6))
ax2 = plt.axes()
ax2.bar(obitos_conf.index, obitos_conf, label='Confirmados')
ax2.bar(obitos_desc.index, obitos_desc, bottom=obitos_conf, label='Descartados')
ax2.bar(obitos_susp.index, obitos_susp, bottom=obitos_conf+obitos_desc, label='Suspeitos')
ax2.plot(rm_obitos, color='r', label='Média móvel dos últimos 14d')
ax2.legend()
ax2.set(title='Composição do índice de Mortos por COVID no ES nos últimos 90 dias', xlabel='Data de Óbito',
        ylabel='Quantidade de Mortos no dia')
# Out:
# [Text(0, 0.5, 'Quantidade de Mortos no dia'),
#  Text(0.5, 0, 'Data de Óbito'),
#  Text(0.5, 1.0, 'Composição do índice de Mortos por COVID no ES nos últimos 90 dias')]

# %% [markdown]
# Filtrando os dados apenas para a GV (Serra, Cariacica, Viana, Vila Velha e Vitória)

# %%
dfgv = df.query("Municipio == ['VILA VELHA','VITORIA','CARIACICA','SERRA','VIANA']")
dfgv
# Out:
#        DataNotificacao DataCadastro DataDiagnostico DataColeta_RT_PCR  \
# 5           2020-08-19   2020-08-19      2020-08-12        2020-08-19
# 10          2020-08-19   2020-08-19      2020-08-19               NaN
# 11          2020-08-19   2020-08-19      2020-08-07               NaN
# 12          2020-08-19   2020-08-19      2020-08-05               NaN
# 20          2020-08-19   2020-08-19      2020-07-29        2020-07-10
# ...                ...          ...             ...               ...
# 305462      2020-02-27   2020-04-16      2020-02-15        2020-02-27
# 305463      2020-02-27   2020-04-16      2020-02-09        2020-02-28
# 305464      2020-02-27   2020-04-16      2020-02-16        2020-02-27
# 305465      2020-02-27   2020-04-16      2020-02-15        2020-02-27
# 305467      2020-02-25   2020-04-16      2020-02-13        2020-02-26
#
#        DataColetaTesteRapido DataEncerramento DataObito Classificacao  \
# 5                        NaN              NaN       NaT      Suspeito
# 10                2020-08-19              NaN       NaT      Suspeito
# 11                2020-08-19              NaN       NaT      Suspeito
# 12                2020-08-19       2020-08-19       NaT   Descartados
# 20                       NaN              NaN       NaT   Confirmados
# ...                      ...              ...       ...           ...
# 305462                   NaN       2020-04-16       NaT   Descartados
# 305463                   NaN       2020-04-16       NaT   Descartados
# 305464                   NaN       2020-04-16       NaT   Descartados
# 305465                   NaN       2020-04-16       NaT   Descartados
# 305467                   NaN       2020-04-16       NaT   Descartados
#
#                        Evolucao CriterioConfirmacao  ... ComorbidadeRenal  \
# 5                             -                   -  ...              Não
# 10                            -                   -  ...              Não
# 11                            -                   -  ...              Não
# 12                            -                   -  ...              Não
# 20                         Cura        Laboratorial  ...              Não
# ...                         ...                 ...  ...              ...
# 305462                 Ignorado        Laboratorial  ...              Não
# 305463                 Ignorado        Laboratorial  ...              Não
# 305464                 Ignorado        Laboratorial  ...              Não
# 305465                 Ignorado        Laboratorial  ...              Não
# 305467  Óbito por outras causas        Laboratorial  ...              Não
#
#        ComorbidadeDiabetes ComorbidadeTabagismo ComorbidadeObesidade  \
# 5                      Não                  Não                  Não
# 10                     Não                  Não                  Não
# 11                     Não                  Não                  Não
# 12                     Não                  Não                  Não
# 20                     Não                  Não                  Não
# ...                    ...                  ...                  ...
# 305462                 Não                  Não                  Não
# 305463                 Não                  Não                  Não
# 305464                 Sim                  Não                  Não
# 305465                 Não                  Não                  Não
# 305467                 Não                  Não                  Não
#
#        FicouInternado   ViagemBrasil ViagemInternacional ProfissionalSaude  \
# 5       Não Informado  Não Informado       Não Informado               Não
# 10      Não Informado            Não       Não Informado               Não
# 11                Não            Não                 Não               Não
# 12      Não Informado  Não Informado       Não Informado               Não
# 20                Não            Não                 Não               Sim
# ...               ...            ...                 ...               ...
# 305462  Não Informado            Não                 Não               Não
# 305463  Não Informado       Ignorado                 Sim          Ignorado
# 305464            Não            Não                 Não               Não
# 305465            Não            Não                 Não               Não
# 305467            Não            Não                 Sim               Não
#
#        PossuiDeficiencia   MoradorDeRua
# 5                    Não            Não
# 10                   Não            Não
# 11                   Não            Não
# 12                   Não            Não
# 20                   Não            Não
# ...                  ...            ...
# 305462     Não Informado  Não Informado
# 305463     Não Informado  Não Informado
# 305464     Não Informado  Não Informado
# 305465     Não Informado  Não Informado
# 305467     Não Informado  Não Informado
#
# [161030 rows x 37 columns]

# %%
dfgv_confirmados = dfgv.query("Classificacao == 'Confirmados'")
dfgv_confirmados
# Out:
#        DataNotificacao DataCadastro DataDiagnostico DataColeta_RT_PCR  \
# 20          2020-08-19   2020-08-19      2020-07-29        2020-07-10
# 29          2020-08-19   2020-08-19      2020-06-20        2020-06-25
# 36          2020-08-19   2020-08-19      2020-08-07        2020-08-07
# 66          2020-08-19   2020-08-19      2020-08-04        2020-08-18
# 67          2020-08-19   2020-08-19      2020-08-18               NaN
# ...                ...          ...             ...               ...
# 305384      2020-03-13   2020-04-14      2020-03-12        2020-03-13
# 305392      2020-03-13   2020-04-14      2020-03-13        2020-03-15
# 305393      2020-03-13   2020-04-14      2020-03-10        2020-03-12
# 305452      2020-03-06   2020-04-14      2020-03-04        2020-03-06
# 305459      2020-02-29   2020-04-14      2020-02-22        2020-02-29
#
#        DataColetaTesteRapido DataEncerramento DataObito Classificacao  \
# 20                       NaN              NaN       NaT   Confirmados
# 29                       NaN       2020-07-03       NaT   Confirmados
# 36                       NaN              NaN       NaT   Confirmados
# 66                       NaN              NaN       NaT   Confirmados
# 67                       NaN              NaN       NaT   Confirmados
# ...                      ...              ...       ...           ...
# 305384                   NaN       2020-04-15       NaT   Confirmados
# 305392                   NaN       2020-05-08       NaT   Confirmados
# 305393                   NaN       2020-05-07       NaT   Confirmados
# 305452                   NaN       2020-05-08       NaT   Confirmados
# 305459                   NaN       2020-04-18       NaT   Confirmados
#
#        Evolucao CriterioConfirmacao  ... ComorbidadeRenal ComorbidadeDiabetes  \
# 20         Cura        Laboratorial  ...              Não                 Não
# 29         Cura        Laboratorial  ...              Não                 Sim
# 36            -                   -  ...              Não                 Não
# 66            -                   -  ...              Não                 Não
# 67            -        Laboratorial  ...              Não                 Não
# ...         ...                 ...  ...              ...                 ...
# 305384     Cura        Laboratorial  ...              Não                 Sim
# 305392     Cura        Laboratorial  ...              Não                 Não
# 305393     Cura        Laboratorial  ...              Não                 Não
# 305452     Cura        Laboratorial  ...              Não                 Não
# 305459     Cura        Laboratorial  ...              Não                 Não
#
#        ComorbidadeTabagismo ComorbidadeObesidade FicouInternado  \
# 20                      Não                  Não            Não
# 29                      Não                  Não            Não
# 36                      Não                  Não  Não Informado
# 66                      Não                  Não  Não Informado
# 67                      Não                  Não  Não Informado
# ...                     ...                  ...            ...
# 305384                  Não                  Não            Não
# 305392                  Não                  Não  Não Informado
# 305393                  Não                  Não  Não Informado
# 305452                  Não                  Não  Não Informado
# 305459                  Não                  Não  Não Informado
#
#          ViagemBrasil ViagemInternacional ProfissionalSaude PossuiDeficiencia  \
# 20                Não                 Não               Sim               Não
# 29                Não                 Não               Não               Não
# 36      Não Informado       Não Informado          Ignorado               Não
# 66      Não Informado       Não Informado          Ignorado               Não
# 67      Não Informado       Não Informado               Não               Não
# ...               ...                 ...               ...               ...
# 305384            Não                 Não          Ignorado     Não Informado
# 305392  Não Informado                 Sim               Sim     Não Informado
# 305393  Não Informado                 Sim               Não     Não Informado
# 305452  Não Informado                 Sim               Não     Não Informado
# 305459  Não Informado                 Sim     Não Informado     Não Informado
#
#          MoradorDeRua
# 20                Não
# 29                Não
# 36                Não
# 66                Não
# 67                Não
# ...               ...
# 305384  Não Informado
# 305392  Não Informado
# 305393  Não Informado
# 305452  Não Informado
# 305459  Não Informado
#
# [52514 rows x 37 columns]

# %%
casos_gv = dfgv_confirmados.pivot_table('Classificacao','DataNotificacao',aggfunc='count').Classificacao
rm_casos_gv = casos_gv.rolling(14).mean()

# %%
fig3 = plt.figure(figsize=(12,6))
ax3 = plt.axes()
ax3.bar(casos_gv[-90:-1].index, casos_gv[-90:-1],label='Confirmados')
ax3.plot(rm_casos_gv[-90:-1],color='r',label='Média Móvel 14d')
ax3.legend()
ax3.set(title='Casos confirmados de COVID na GV nos últimos 90d', xlabel='Data da Notificação',
        ylabel='Pacientes notificados')
# Out:
# [Text(0, 0.5, 'Pacientes notificados'),
#  Text(0.5, 0, 'Data da Notificação'),
#  Text(0.5, 1.0, 'Casos confirmados de COVID na GV nos últimos 90d')]

# %%
total_obitos_gv = dfgv.query("DataObito > '2020'").pivot_table('DataNotificacao','DataObito','Classificacao',aggfunc='count')
total_obitos_gv
# Out:
# Classificacao  Confirmados  Descartados  Suspeito
# DataObito
# 2020-04-01             3.0          NaN       NaN
# 2020-04-02             3.0          NaN       NaN
# 2020-04-03             NaN          1.0       NaN
# 2020-04-05             NaN          1.0       NaN
# 2020-04-06             NaN          NaN       1.0
# ...                    ...          ...       ...
# 2020-08-15             9.0          2.0       2.0
# 2020-08-16             4.0          NaN       NaN
# 2020-08-17             9.0          3.0       2.0
# 2020-08-18             6.0          2.0       NaN
# 2020-08-19             3.0          NaN       NaN
#
# [137 rows x 3 columns]

# %%
# Restringindo a data para os últimos 90d

obitos_conf_gv = total_obitos_gv.Confirmados[-90:-1]
obitos_susp_gv = total_obitos_gv.Suspeito[-90:-1]
obitos_desc_gv = total_obitos_gv.Descartados[-90:-1]
rm_obitos_gv = obitos_conf_gv.add(obitos_desc_gv.add(obitos_susp_gv, fill_value=0), fill_value=0).rolling(14).mean()

# %%
fig4 = plt.figure(figsize=(12,6))
ax4 = plt.axes()
ax4.bar(obitos_conf_gv.index, obitos_conf_gv, label='Confirmados')
ax4.bar(obitos_desc_gv.index, obitos_desc_gv, bottom=obitos_conf_gv, label='Descartados')
ax4.bar(obitos_susp_gv.index, obitos_susp_gv, bottom=obitos_conf_gv+obitos_desc_gv, label='Suspeitos')
ax4.plot(rm_obitos_gv, color='r', label='Média móvel dos últimos 14d')
ax4.legend()
ax4.set(title='Composição do índice de Mortos por COVID na GV nos últimos 90 dias', xlabel='Data de Óbito',
        ylabel='Quantidade de Mortos no dia')
# Out:
# [Text(0, 0.5, 'Quantidade de Mortos no dia'),
#  Text(0.5, 0, 'Data de Óbito'),
#  Text(0.5, 1.0, 'Composição do índice de Mortos por COVID na GV nos últimos 90 dias')]

# %%
# Retirando os descartados do plot e da média móvel

rm2_obitos_gv = obitos_conf_gv.add(obitos_susp_gv, fill_value=0).rolling(14).mean()
rm3_obitos_gv = obitos_desc_gv.fillna(0).rolling(14).mean()

# %%
fig5 = plt.figure(figsize=(12,6))
ax5 = plt.axes()
ax5.bar(obitos_conf_gv.index, obitos_conf_gv, label='Confirmados')
ax5.bar(obitos_desc_gv.index, obitos_desc_gv, label='Descartados')
ax5.bar(obitos_susp_gv.index, obitos_susp_gv, bottom=obitos_conf_gv, label='Suspeitos')
ax5.plot(rm3_obitos_gv, color='magenta', label='Média móvel Descartados 14d')
ax5.plot(rm2_obitos_gv, color='r', label='Média móvel Conf+Susp 14d')
ax5.legend()
ax5.set(title='Composição do índice de Mortos por COVID na GV nos últimos 90 dias', xlabel='Data de Óbito',
        ylabel='Quantidade de Mortos no dia')
# Out:
# [Text(0, 0.5, 'Quantidade de Mortos no dia'),
#  Text(0.5, 0, 'Data de Óbito'),
#  Text(0.5, 1.0, 'Composição do índice de Mortos por COVID na GV nos últimos 90 dias')]
